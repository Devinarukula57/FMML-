# %% [markdown]
# <a href="https://colab.research.google.com/github/Devinarukula57/FMML-/blob/main/FMML__Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 13:03:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  63.1MB/s    in 1.1s
#
# 2025-03-13 13:03:40 (63.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3912 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 248  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6980   1708.05929v3  Anomaly detection has numerous applications an...    cs
# 26762  1611.08195v2  In this paper, we propose an approach to the d...    cs
# 30639  1712.08838v1  We propose a recurrent variational auto-encode...    cs
# 23086  cs/0003065v1  Fractal image compression, Culik's image compr...    cs
# 21680   0909.5194v2  We propose Dirichlet Process mixtures of Gener...  stat
# ...             ...                                                ...   ...
# 29988  1711.04161v5  From the frame/clip-level feature learning to ...    cs
# 22981  1712.03281v1  In this paper, we study the general problem of...  stat
# 21189  1709.09433v1  This paper introduces a Fuzzy Logic framework ...    cs
# 6350   1611.05934v1  As deep neural networks continue to revolution...  stat
# 24821   1412.1123v3  Contour detection has been a fundamental compo...    cs
#
#                                                    title  year  \
# 6980   Explaining Anomalies in Groups with Characteri...  2017
# 26762  Domain Adaptation by Mixture of Alignments of ...  2016
# 30639  Texture Synthesis with Recurrent Variational A...  2017
# 23086  Image Compression with Iterated Function Syste...  2000
# 21680  Dirichlet Process Mixtures of Generalized Line...  2009
# ...                                                  ...   ...
# 29988  End-to-end Video-level Representation Learning...  2017
# 22981  Fast Low-Rank Matrix Estimation without the Co...  2017
# 21189  Scene learning, recognition and similarity det...  2017
# 6350   Increasing the Interpretability of Recurrent N...  2016
# 24821  DeepEdge: A Multi-Scale Bifurcated Deep Networ...  2014
#
#                                                 keywords
# 6980   [detection, applications, complementary, liter...
# 26762  [adaptation, knowledge, alignments, statistics...
# 30639  [recurrent, variational, synthesis, synthesize...
# 23086  [compression, compression, prediction, decompo...
# 21680  [dirichlet, generalized, nonparametric, regres...
# ...                                                  ...
# 29988  [frameclip, representation, recognition, devel...
# 22981  [optimizing, constraints, invocations, decompo...
# 21189  [introduces, framework, recognition, similarit...
# 6350   [revolutionize, application, increasing, under...
# 24821  [detection, fundamental, component, segmentati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6980     [detection, applications, complementary, liter...
# 26762    [adaptation, knowledge, alignments, statistics...
# 30639    [recurrent, variational, synthesis, synthesize...
# 23086    [compression, compression, prediction, decompo...
# 21680    [dirichlet, generalized, nonparametric, regres...
#                                ...
# 22582    [selection, regression, candidate, explanatory...
# 23504    [localization, underpinning, applications, rel...
# 34760    [expresses, sentiment, particular, exploited, ...
# 24708    [automated, extraction, information, cognitive...
# 15072    [describes, automatic, inference, structural, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8816 words.
# Out of those 4635 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1b517eeb-f0bd-4b17-a8db-6e802c7b8204" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b517eeb-f0bd-4b17-a8db-6e802c7b8204")) {                    Plotly.newPlot(                        "1b517eeb-f0bd-4b17-a8db-6e802c7b8204",                        [{"x":["attention","anomalous","desiderata","detection","interpretable","satisfies","furthermore","parallelizable","engineers","potentially","anomalies","construct","subspaces","repeating","descriptive","characterizing","perspective","dimensional","providing","description","literature","explaining","practitioners","signatures","complementary","arbitrary","explanation","identifying","instances","different","simultaneously","applications","properties","effectiveness","interpretation","developing","evaluations","recurring","adaptation","benchmark","investigate","alignments","knowledge","distributions","maintaining","motivation","classifier","separation","statistics","supervised","specifically","connected","evaluated","experiments","quantitative","invariant","synthesizer","correlation","explicitly","rotational","performance","qualitative","neighboring","evaluation","functions","generates","recurrent","variational","intensity","synthesis","partially","prediction","compression","demonstrate","techniques","evolution","significant","discusses","predictions","technique","coefficient","similarity","unification","transformed","transformation","decomposition","compressed","coefficients","algorithmically","resorting","relations","processing","dirichlet","continuous","unbiasedness","comparing","empirically","nonparametric","accommodates","covariates","inference","including","supported","generalized","compactly","processes","corresponding","categorical","conditions","regression","asymptotic","responses","vietnamese","available","experimental","exception","structure","approaches","classification","methodology","segmentation","outperforms","illustrated","approximations","filtering","adaptively","numerical","bipartite","objective","realizations","representations","linearnonlinear","theoretical","multivariate","autocorrelation","functional","considerations","independent","dependency","languages","parameters","uncorrupted","prevalence","syntactic","existence","indication","determined","distributed","remaining","interpret","principles","parameter","recoverability","corrupted","underlying","restrictive","characterizes","perspectives","particular","computational","assumption","collecting","statistical","therefore","prohibitive","coarsening","distribution","characterization","complicated","distinction","observational","observations","questions","admissibility","corresponds","highlight","procedural","probability","robustness","reasonable","generating","complexities","completely","procedures","incomplete","probabilistic","distributional","equivalence","sufficient","condition","assumptions","distinguish","outperforming","importantly","framework","exploited","formulation","appealing","sentiment","perturbing"],"y":[190,8,5,353,32,9,156,5,7,52,9,91,20,3,13,19,77,189,86,71,125,14,11,6,42,85,15,90,113,772,119,449,191,183,65,57,56,2,75,210,131,8,315,129,40,21,148,22,61,207,182,70,145,634,81,65,3,74,57,7,882,61,20,273,222,50,140,57,35,36,45,254,37,572,370,65,251,36,82,235,22,147,4,20,64,56,32,40,4,7,87,311,24,109,1,78,70,12,2,2,223,248,16,64,3,103,133,13,126,132,19,25,5,288,375,3,324,445,498,73,198,249,11,27,66,24,85,5,157,3,226,0,171,20,3,44,9,135,47,97,251,2,4,41,33,6,39,115,20,18,29,122,1,19,116,9,17,18,223,313,58,23,150,122,9,1,214,28,32,8,8,65,59,1,24,32,4,161,102,38,103,15,45,39,32,168,25,22,59,45,50,35,23,24,576,34,78,15,35,1],"type":"bar"},{"x":["attention","anomalous","desiderata","detection","inter ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4635,), (4635, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7925

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Theory</span> <span style=''>for</span> <span style=''>Optical</span> <span style=''>flow</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transport</span> <span style=''>on</span> <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Manifolds</span> <br/><br/><span style=''>An</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>articulation</span> <span style=''>manifold</span> <span style=''>(IAM)</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>images</span> <span style=''>formed</span> <span style=''>when</span> <span style=''>an</span> <span style=''>object</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>articulated</span> <span style=''>in</span> <span style=''>front</span> <span style=''>of</span> <span style=''>a</span> <span style=''>camera</span> <span style=''>IAMs</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.49879518072289164);'>processing</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>where</span> <span style=''>they</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3297872340425532);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3297872340425532);'>dimensional</span> <span style=''>images</span> <span style=''>To</span> <span style=''>date</span> <span style=''>IAMs</span> <span style=''>have</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>as</span> <span style=''>embedded</span> <span style=''>submanifolds</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>spaces</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unfortunately</span> <span style=''>their</span> <span style=''>promise</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style=''>realized</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>because</span> <span style=''>real</span> <span style=''>world</span> <span style=''>imagery</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>contains</span> <span style=''>sharp</span> <span style=''>edges</span> <span style=''>that</span> <span style=''>render</span> <span style=''>an</span> <span style=''>IAM</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>isometric</span> <span style=''>to</span> <span style=''>the</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3297872340425532);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>space</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>metric</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>tools</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multidimensional</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <span style=''>and</span> <span style=''>Its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style=''>Accuracy</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>employed</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>analysis</span> <span style=''>They</span> <span style=''>consist</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observable</span> <span style=''>and</span> <span style=''>hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>given</span> <span style=''>data</span> <span style=''>and</span> <span style=''>their</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>respectively</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>pointed</span> <span style=''>out</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>these</span> <span style=''>models</span> <span style=''>because</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>produces</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>singularities</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>space</span> <span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>a</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algebraic</span> <span style=''>geometry</span> <span style=''>has</span> <span style=''>allowed</span> <span style=''>us</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>when</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>However</span> <span style=''>how</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Loop</span> <span style=''>Cutset</span> <span style=''>Problem</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>Finding</span> <span style=''>such</span> <span style=''>a</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>step</span> <span style=''>in</span> <span style=''>Pearls</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>Our</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>called</span> <span style=''>Repeated</span> <span style=''>WGuessI</span> <span style=''>outputs</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>after</span> <span style=''>O(c</span> <span style=''>6k</span> <span style=''>k</span> <span style=''>n)</span> <span style=''>steps</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>at</span> <span style=''>least</span> <span style=''>1</span> <span style=''>(1</span> <span style=''>over6k)c</span> <span style=''>6k)</span> <span style=''>where</span> <span style=''>c1</span> <span style=''>is</span> <span style=''>a</span> <span style=''>constant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>by</span> <span style=''>the</span> <span style=''>user</span> <span style=''>k</span> <span style=''>is</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>weight</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>and</span> <span style=''>n</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>vertices</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>that</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>WRA</span> <span style=''>often</span> <span style=''>finds</span> <span style=''>a</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>that</span> <span style=''>is</span> <span style=''>closer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>than</span> <span style=''>the</span> <span style=''>ones</span> <span style=''>found</span> <span style=''>by</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>known</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Doctor</span> <span style=''>Just</span> <span style=''>Wont</span> <span style=''>Accept</span> <span style=''>That</span> <br/><br/><span style=''>Calls</span> <span style=''>to</span> <span style=''>arms</span> <span style=''>to</span> <span style=''>build</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>models</span> <span style=''>express</span> <span style=''>a</span> <span style=''>well</span> <span style=''>founded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discomfort</span> <span style=''>with</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Should</span> <span style=''>a</span> <span style=''>software</span> <span style=''>agent</span> <span style=''>that</span> <span style=''>does</span> <span style=''>not</span> <span style=''>even</span> <span style=''>know</span> <span style=''>what</span> <span style=''>a</span> <span style=''>loan</span> <span style=''>is</span> <span style=''>decide</span> <span style=''>who</span> <span style=''>qualifies</span> <span style=''>for</span> <span style=''>one</span> <span style=''>Indeed</span> <span style=''>we</span> <span style=''>ought</span> <span style=''>to</span> <span style=''>be</span> <span style=''>cautious</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>injecting</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>(or</span> <span style=''>anything</span> <span style=''>else</span> <span style=''>for</span> <span style=''>that</span> <span style=''>matter)</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>where</span> <span style=''>there</span> <span style=''>may</span> <span style=''>be</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>causing</span> <span style=''>social</span> <span style=''>harm</span> <span style=''>However</span> <span style=''>claims</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stakeholders</span> <span style=''>just</span> <span style=''>wont</span> <span style=''>accept</span> <span style=''>that</span> <span style=''>do</span> <span style=''>not</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foundation</span> <span style=''>for</span> <span style=''>a</span> <span style=''>proposed</span> <span style=''>field</span> <span style=''>of</span> <span style=''>study</span> <span style=''>For</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>advance</span> <span style=''>we</span> <span style=''>must</span> <span style=''>ask</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>What</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precisely</span> <span style=''>wont</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stakeholders</span> <span style=''>accept</span> <span style=''>What</span> <span style=''>do</span> <span style=''>they</span> <span style=''>want</span> <span style=''>Are</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desiderata</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style=''>Are</span> <span style=''>they</span> <span style=''>feasible</span> <span style=''>In</span> <span style=''>or ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13354700854700854)
# 	evaluation (0.09722222222222222)
# 	segmentation (0.07051282051282051)
# 	architecture (0.08653846153846154)
# 	processing (0.11075498575498575)
# 	information (0.25462962962962965)
# 	detection (0.1257122507122507)
# 	different (0.27492877492877493)
# 	recognition (0.14316239316239315)
# 	convolutional (0.13817663817663817)
#
# Some Statistics words are:
# 	theoretical (0.14708835341365462)
# 	variables (0.13453815261044177)
# 	stochastic (0.13704819277108435)
# 	statistical (0.1501004016064257)
# 	estimation (0.16817269076305222)
# 	algorithm (0.38805220883534136)
# 	distribution (0.1932730923694779)
# 	dimensional (0.18825301204819278)
# 	inference (0.20481927710843373)
# 	regression (0.17921686746987953)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="49396396-2cd6-4463-8afe-81194945623e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49396396-2cd6-4463-8afe-81194945623e")) {                    Plotly.newPlot(                        "49396396-2cd6-4463-8afe-81194945623e",                        [{"x":["attention","anomalous","desiderata","detection","interpretable","satisfies","furthermore","parallelizable","engineers","potentially","anomalies","construct","subspaces","repeating","descriptive","characterizing","perspective","dimensional","providing","description","literature","explaining","practitioners","signatures","complementary","arbitrary","explanation","identifying","instances","different","simultaneously","applications","properties","effectiveness","interpretation","developing","evaluations","recurring","adaptation","benchmark","investigate","alignments","knowledge","distributions","maintaining","motivation","classifier","separation","statistics","supervised","specifically","connected","evaluated","experiments","quantitative","invariant","synthesizer","correlation","explicitly","rotational","performance","qualitative","neighboring","evaluation","functions","generates","recurrent","variational","intensity","synthesis","partially","prediction","compression","demonstrate","techniques","evolution","significant","discusses","predictions","technique","coefficient","similarity","unification","transformed","transformation","decomposition","compressed","coefficients","algorithmically","resorting","relations","processing","dirichlet","continuous","unbiasedness","comparing","empirically","nonparametric","accommodates","covariates","inference","including","supported","generalized","compactly","processes","corresponding","categorical","conditions","regression","asymptotic","responses","vietnamese","available","experimental","exception","structure","approaches","classification","methodology","segmentation","outperforms","illustrated","approximations","filtering","adaptively","numerical","bipartite","objective","realizations","representations","linearnonlinear","theoretical","multivariate","autocorrelation","functional","considerations","independent","dependency","languages","parameters","uncorrupted","prevalence","syntactic","existence","indication","determined","distributed","remaining","interpret","principles","parameter","recoverability","corrupted","underlying","restrictive","characterizes","perspectives","particular","computational","assumption","collecting","statistical","therefore","prohibitive","coarsening","distribution","characterization","complicated","distinction","observational","observations","questions","admissibility","corresponds","highlight","procedural","probability","robustness","reasonable","generating","complexities","completely","procedures","incomplete","probabilistic","distributional","equivalence","sufficient","condition","assumptions","distinguish","outperforming","importantly","framework","exploited","formulation","appealing","sentiment","perturbing","according","formalize","subnetworks","generated","regularizer","transform","recursive","naturally","collection","ensembles","significantly","generalize","combination","posteriors","complexity","efficient","recordings","collected","information","representing","synthetic","considering","euclidean","resolution","fingerprint","investigations","terrorist","coherence","identification","decomposed","orientation","recognition","comparison","algorithm","resources","evaluating","homogeneous","utterances","convolutional","predicting","conventional","systematically","established","audiences","advantages","presentation","supporting","linguistic","containing","accuracies","essential","automatically","sufficient ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	linearnonlinear
# 	inordinately
# 	macroeconomic
# 	quantiles
# 	frequentist
# 	dependences
# 	maximisation
# 	trainability
# 	equitability
# 	mitigates
# 	kronecker
# 	layerwise
# 	thresholded
# 	particulars
# 	calculable
# 	inductively
# 	unprocessed
# 	reparametrizations
# 	temperatures
# 	inhibited
# Some words which never appear in Statistics papers:
# 	engineers
# 	synthesizer
# 	algorithmically
# 	vietnamese
# 	terrorist
# 	audiences
# 	presentation
# 	quantifiers
# 	unawareness
# 	adequately
# 	decidability
# 	rustichini
# 	propositional
# 	inflectional
# 	grammatically
# 	morphologically
# 	discloses
# 	manifestation
# 	participation
# 	geographic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.056701818737582e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7341666666666666
